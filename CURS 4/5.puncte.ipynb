# %%
import pandas as pd

# %%
df = pd.read_csv("puncte.csv")
df
# Out:
#         coord_x     coord_y categoria
# 0     74.072254  284.437166         a
# 1     90.128852  301.739523         a
# 2     93.075842  243.093766         a
# 3     31.039321  306.538233         a
# 4     82.391962  260.409235         a
# ..          ...         ...       ...
# 286  626.417561  175.799544         b
# 287  622.514432   95.837446         b
# 288  584.520959  156.808434         b
# 289  575.401641   93.879072         b
# 290  573.868439  123.469467         b
#
# [291 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df["categoria"]=="a");

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model
# Out:
# KNeighborsClassifier()

# %%
model.fit(df[["coord_x", "coord_y"]], df["categoria"])
# Out:
# KNeighborsClassifier()

# %%
model.predict([[100, 200]])
# Out:
# C:\Users\Stelian DRAGNE\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['a'], dtype=object)

# %%
model.predict([[200, 600]])
# Out:
# C:\Users\Stelian DRAGNE\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['b'], dtype=object)
