# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apartamente = [(37, 65), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[ apartamente[:,0].argsort()]

# %%
print(apartamente)
# Out:
# [[ 37  65]
#  [ 41  75]
#  [ 55  80]
#  [ 60  95]
#  [ 72 198]
#  [ 80 120]
#  [ 82 205]
#  [ 92 205]
#  [145 367]
#  [170 400]]

# %%
suprafete, preturi = apartamente[:, 0], apartamente[:, 1]

# %%
suprafete
# Out:
# array([ 37,  41,  55,  60,  72,  80,  82,  92, 145, 170])

# %%
plt.scatter(suprafete, preturi);
plt.xlabel("Suprafata");
plt.ylabel("Preturi");

# %%
plt.scatter(suprafete, preturi);
plt.xlabel("Suprafata")
plt.ylabel("Preturi");

# %% [markdown]
# # pip install scikit-learn

# %% [markdown]
# # import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %% [markdown]
# # In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# # On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
suprafete
# Out:
# array([ 37,  41,  55,  60,  72,  80,  82,  92, 145, 170])

# %%
suprafete.reshape(-1, 1)
# Out:
# array([[ 37],
#        [ 41],
#        [ 55],
#        [ 60],
#        [ 72],
#        [ 80],
#        [ 82],
#        [ 92],
#        [145],
#        [170]])

# %%
model.fit(suprafete.reshape(-1, 1), preturi)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([2.69778312]), np.float64(-43.99511191455963))

# %%
def f(x):
    return 2.69778312 * x - 43.99511191455963

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, list(map(f, suprafete)));
