# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression

# %%
make_regression(n_samples=3, n_features=1)
# Out:
# (array([[1.13614745],
#         [0.26984775],
#         [0.72824967]]),
#  array([73.55758037, 17.47074979, 47.14905964]))

# %%
make_regression(n_samples=3, n_features=2)
# Out:
# (array([[-0.85938752,  0.15317956],
#         [-0.79065714, -0.32983696],
#         [ 0.29973633,  0.91892864]]),
#  array([-36.90862156, -37.89475125,  21.00665088]))

# %%
make_regression(n_samples=3, n_features=1)
# Out:
# (array([[0.12912334],
#         [0.04248412],
#         [0.84044408]]),
#  array([ 2.57065835,  0.84579718, 16.73202215]))

# %%
x, y = make_regression(n_samples=10, n_features=1)

# %%
x, y = make_regression(n_samples=10, n_features=1)
plt.scatter(x, y);

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y);
plt.plot(x, model.coef_ * x + model.intercept_);

# %% [markdown]
# # Adaugare Noise (ZGOMOT)

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
model = LinearRegression()
model.fit(x, y)
plt.scatter(x, y);
plt.plot(x, model.coef_ * x + model.intercept_);

# %%
model.predict([[1]])
# Out:
# array([29.23378337])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x, y)
# Out:
# KNeighborsRegressor()

# %%
knn_model.predict([[1]])
# Out:
# array([25.82451032])
