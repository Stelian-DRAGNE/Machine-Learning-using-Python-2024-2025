# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, load_digits
from sklearn.cluster import KMeans

# %%
x, y = load_digits(return_X_y=True)
x.shape, y.shape
# Out:
# ((1797, 64), (1797,))

# %%
x[20]
# Out:
# array([ 0.,  0.,  3., 13., 11.,  7.,  0.,  0.,  0.,  0., 11., 16., 16.,
#        16.,  2.,  0.,  0.,  4., 16.,  9.,  1., 14.,  2.,  0.,  0.,  4.,
#        16.,  0.,  0., 16.,  2.,  0.,  0.,  0., 16.,  1.,  0., 12.,  8.,
#         0.,  0.,  0., 15.,  9.,  0., 13.,  6.,  0.,  0.,  0.,  9., 14.,
#         9., 14.,  1.,  0.,  0.,  0.,  2., 12., 13.,  4.,  0.,  0.])

# %%
prima_imagine = x[20]
prima_imagine = prima_imagine.reshape(8, 8)

# %%
plt.imshow(prima_imagine);

# %%
iris = load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris.target[0], iris.target_names
# Out:
# (np.int64(0), array(['setosa', 'versicolor', 'virginica'], dtype='<U10'))

# %%
data_sepale = iris.data[:, :2]
# data_sepale

# %%
plt.scatter(data_sepale[:, 0], data_sepale[:, 1]);

# %%
plt.scatter(data_sepale[:, 0], data_sepale[:, 1], c=iris.target);

# %%
data_petale = iris.data[:, 2:]
plt.scatter(data_petale[:, 0], data_petale[:, 1], c=iris.target);

# %%
model = KMeans(n_clusters=3)
model.fit(data_petale[:, :2])
plt.scatter(data_petale[:, 0], data_petale[:, 1], c=model.labels_);
